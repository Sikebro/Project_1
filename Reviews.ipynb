# %%
#Importing and applying all dependencies 
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
#Getting path from the resouce file and reading the information and putting into a dataframe
air_bnb_data = Path("Resources/Listings.csv")
air_bnb_data_df = pd.read_csv(air_bnb_data, encoding = "ISO-8859-1")
# Out:
# C:\Users\shils\AppData\Local\Temp\ipykernel_2744\3008735880.py:3: DtypeWarning: Columns (5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   air_bnb_data_df = pd.read_csv(air_bnb_data, encoding = "ISO-8859-1")

# %%
#Displaying the dataframe to see what information is there to work with.
air_bnb_data_df.head(10)
# Out:
#    listing_id                                               name   host_id  \
# 0      281420     Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 2     4082273                Lovely apartment with Terrace, 60m2  19252768
# 3     4797344                Cosy studio (close to Eiffel tower)  10668311
# 4     4823489   Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
# 5     4898654                 NEW - Charming apartment Le Marais    505535
# 6     6021700                  2P - Entre Bastille et Republique   8053690
# 7     6945740             57sqm btw. Bastille & PÃÂ¨re Lachaise   5924709
# 8     7491966  Charming appartment near the Parc Buttes Chaumont  35812762
# 9     7849932                  Bel appartement plein de charme !  20833291
#
#    host_since                 host_location host_response_time  \
# 0  2011-12-03  Paris, Ile-de-France, France                NaN
# ...

# %%
#creating dataframe for number of host for years 2008,2009,2010 & 2019,2020,2021
#For the year 2008
host_2008_start = "2008-01-01"
host_2008_end = "2008-31-12"
host_2008 = air_bnb_data_df.loc[((air_bnb_data_df["host_since"] >= host_2008_start) & (air_bnb_data_df["host_since"] <= host_2008_end))]
count_2008 = host_2008["host_since"].count()
#For the year 2009
host_2009_start = "2009-01-01"
host_2009_end = "2009-31-12"
host_2009 = air_bnb_data_df.loc[((air_bnb_data_df["host_since"] >= host_2009_start) & (air_bnb_data_df["host_since"] <= host_2009_end))]
count_2009 = host_2009["host_since"].count()
#For the year 2010
host_2010_start = "2010-01-01"
host_2010_end = "2010-31-12"
host_2010 = air_bnb_data_df.loc[((air_bnb_data_df["host_since"] >= host_2010_start) & (air_bnb_data_df["host_since"] <= host_2010_end))]
count_2010 = host_2010["host_since"].count()

#For the year 2019
host_2019_start = "2019-01-01"
host_2019_end = "2019-31-12"
host_2019 = air_bnb_data_df.loc[((air_bnb_data_df["host_since"] >= host_2019_start) & (air_bnb_data_df["host_since"] <= host_2019_end))]
count_2019 = host_2019["host_since"].count()
#For the year 2020
host_2020_start = "2020-01-01"
host_2020_end = "2020-31-12"
host_2020 = air_bnb_data_df.loc[((air_bnb_data_df["host_since"] >= host_2020_start) & (air_bnb_data_df["host_since"] <= host_2020_end))]
count_2020 = host_2020["host_since"].count()
#For the year 2021
host_2021_start = "2021-01-01"
host_2021_end = "2021-31-12"
host_2021 = air_bnb_data_df.loc[((air_bnb_data_df["host_since"] >= host_2021_start) & (air_bnb_data_df["host_since"] <= host_2021_end))]
count_2021 = host_2021["host_since"].count()

# %%
#Average review score for the years of 2008,2009,2010 and 2019,2020,2021

#Average review score for 2008
average_2008 = host_2008["review_scores_rating"].mean()
average_2008_max = host_2008["review_scores_rating"].max()
average_2008_min = host_2008["review_scores_rating"].min()
avg_08 = average_2008.round()
#Average review score for 2009
average_2009 = host_2009["review_scores_rating"].mean()
average_2009_max = host_2009["review_scores_rating"].max()
average_2009_min = host_2009["review_scores_rating"].min()
avg_09 = average_2009.round()
#Average review score for 2010
average_2010 = host_2010["review_scores_rating"].mean()
average_2010_max = host_2010["review_scores_rating"].max()
average_2010_min = host_2010["review_scores_rating"].min()
avg_10 = average_2010.round()
#Average review score for 2019
average_2019 = host_2019["review_scores_rating"].mean()
average_2019_max = host_2019["review_scores_rating"].max()
average_2019_min = host_2019["review_scores_rating"].min()
avg_19 = average_2019.round()
#Average review score for 2020
average_2020 = host_2020["review_scores_rating"].mean()
average_2020_max = host_2020["review_scores_rating"].max()
average_2020_min = host_2020["review_scores_rating"].min()
avg_20 = average_2020.round()
#Average review score for 2021
average_2021 = host_2021["review_scores_rating"].mean()
average_2021_max = host_2021["review_scores_rating"].max()
average_2021_min = host_2021["review_scores_rating"].min()
avg_21 = average_2021.round()

# %%
#Printing out how host are in each year bracket
print(f"There were {count_2008} hosts who joined in 2008")
print(f"With an average rating of {avg_08} a Maximum of {average_2008_max} and Minimum of {average_2008_min}")
print(f"\nThere were {count_2009} hosts who joined in 2009")
print(f"With an average rating of {avg_09} a Maximum of {average_2009_max} and Minimum of {average_2009_min}")
print(f"\nThere were {count_2010} hosts who joined in 2010")
print(f"With an average rating of {avg_10} a Maximum of {average_2010_max} and Minimum of {average_2010_min}")
print(f"\nThere were {count_2019} hosts who joined in 2019")
print(f"With an average rating of {avg_19} a Maximum of {average_2019_max} and Minimum of {average_2019_min}")
print(f"\nThere were {count_2020} hosts who joined in 2020")
print(f"With an average rating of {avg_20} a Maximum of {average_2020_max} and Minimum of {average_2020_min}")
print(f"\nThere were {count_2021} hosts who joined in 2021")
print(f"With an average rating of {avg_21} a Maximum of {average_2021_max} and Minimum of {average_2021_min}")
# Out:
# There were 65 hosts who joined in 2008
# With an average rating of 94.0 a Maximum of 100.0 and Minimum of 60.0
#
# There were 461 hosts who joined in 2009
# With an average rating of 94.0 a Maximum of 100.0 and Minimum of 20.0
#
# There were 2150 hosts who joined in 2010
# With an average rating of 94.0 a Maximum of 100.0 and Minimum of 20.0
#
# There were 31447 hosts who joined in 2019
# With an average rating of 92.0 a Maximum of 100.0 and Minimum of 20.0
#
# There were 17220 hosts who joined in 2020
# With an average rating of 91.0 a Maximum of 100.0 and Minimum of 20.0
#
# There were 1208 hosts who joined in 2021
# With an average rating of 90.0 a Maximum of 100.0 and Minimum of 20.0

# %%
#Creating a Bar chart to display the number of hosts
x_axis = ["2008","2009","2010","2019","2020","2021"]
y_axis = [count_2008,count_2009,count_2010,count_2019,count_2020,count_2021]

#Creating the bar plot with color, transparency and alignemnt
plt.bar(x_axis,y_axis, color="green", alpha = .75, align = "center")
#Creating the ticks for the bar chart x axis
tick_loc = [value for value in x_axis]
plt.xticks(tick_loc ,x_axis, rotation=60)

plt.title("Number Of Hosts That Joined In Given Year")
plt.xlabel("Year Joined")
plt.ylabel("Number of Hosts")
plt.savefig("Fig1.png")
plt.show()

# %%
#Dataframe with only host_since, city, and review score rating
new_data = air_bnb_data_df[['host_since', 'city', 'review_scores_rating']]
cleaned_data = new_data.dropna()
#Dataframe for Paris and New York
paris_df = cleaned_data.loc[(cleaned_data["city"] == "Paris")]
newyork_df = cleaned_data.loc[(cleaned_data["city"] == "New York")]

#Paris
paris_2008 = paris_df.loc[((paris_df["host_since"] >= host_2008_start) & (paris_df["host_since"] <= host_2008_end))]
paris_2009 = paris_df.loc[((paris_df["host_since"] >= host_2009_start) & (paris_df["host_since"] <= host_2009_end))]
paris_2010 = paris_df.loc[((paris_df["host_since"] >= host_2010_start) & (paris_df["host_since"] <= host_2010_end))]
paris_2019 = paris_df.loc[((paris_df["host_since"] >= host_2019_start) & (paris_df["host_since"] <= host_2019_end))]
paris_2020 = paris_df.loc[((paris_df["host_since"] >= host_2020_start) & (paris_df["host_since"] <= host_2020_end))]
paris_2021 = paris_df.loc[((paris_df["host_since"] >= host_2021_start) & (paris_df["host_since"] <= host_2021_end))]
paris_2008_avg = paris_2008["review_scores_rating"].mean().round()
paris_2009_avg = paris_2009["review_scores_rating"].mean().round()
paris_2010_avg = paris_2010["review_scores_rating"].mean().round()
paris_2019_avg = paris_2019["review_scores_rating"].mean().round()
paris_2020_avg = paris_2020["review_scores_rating"].mean().round()
paris_2021_avg = paris_2021["review_scores_rating"].mean().round()

#New York
newyork_2008 = newyork_df.loc[((newyork_df["host_since"] >= host_2008_start) & (newyork_df["host_since"] <= host_2008_end))]
newyork_2009 = newyork_df.loc[((newyork_df["host_since"] >= host_2009_start) & (newyork_df["host_since"] <= host_2009_end))]
newyork_2010 = newyork_df.loc[((newyork_df["host_since"] >= host_2010_start) & (newyork_df["host_since"] <= host_2010_end))]
newyork_2019 = newyork_df.loc[((newyork_df["host_since"] >= host_2019_start) & (newyork_df["host_since"] <= host_2019_end))]
newyork_2020 = newyork_df.loc[((newyork_df["host_since"] >= host_2020_start) & (newyork_df["host_since"] <= host_2020_end))]
newyork_2021 = newyork_df.loc[((newyork_df["host_since"] >= host_2021_start) & (newyork_df["host_since"] <= host_2021_end))]
newyork_2008_avg = newyork_2008["review_scores_rating"].mean().round()
newyork_2009_avg = newyork_2009["review_scores_rating"].mean().round()
newyork_2010_avg = newyork_2010["review_scores_rating"].mean().round()
newyork_2019_avg = newyork_2019["review_scores_rating"].mean().round()
newyork_2020_avg = newyork_2020["review_scores_rating"].mean().round()
newyork_2021_avg = newyork_2021["review_scores_rating"].mean().round()

# %%
#Max and Min Ratings for paris
paris_2008_max = paris_2008["review_scores_rating"].max()
paris_2009_max = paris_2009["review_scores_rating"].max()
paris_2010_max = paris_2010["review_scores_rating"].max()
paris_2019_max = paris_2019["review_scores_rating"].max()
paris_2020_max = paris_2020["review_scores_rating"].max()
paris_2021_max = paris_2021["review_scores_rating"].max()
paris_2008_min = paris_2008["review_scores_rating"].min()
paris_2009_min = paris_2009["review_scores_rating"].min()
paris_2010_min = paris_2010["review_scores_rating"].min()
paris_2019_min = paris_2019["review_scores_rating"].min()
paris_2020_min = paris_2020["review_scores_rating"].min()
paris_2021_min = paris_2021["review_scores_rating"].min()

# %%
#Max and Min of NewYork
newyork_2008_max = newyork_2008["review_scores_rating"].max()
newyork_2009_max = newyork_2009["review_scores_rating"].max()
newyork_2010_max = newyork_2010["review_scores_rating"].max()
newyork_2019_max = newyork_2019["review_scores_rating"].max()
newyork_2020_max = newyork_2020["review_scores_rating"].max()
newyork_2021_max = newyork_2021["review_scores_rating"].max()
newyork_2008_min = newyork_2008["review_scores_rating"].min()
newyork_2009_min = newyork_2009["review_scores_rating"].min()
newyork_2010_min = newyork_2010["review_scores_rating"].min()
newyork_2019_min = newyork_2019["review_scores_rating"].min()
newyork_2020_min = newyork_2020["review_scores_rating"].min()
newyork_2021_min = newyork_2021["review_scores_rating"].min()

# %%
paris = [paris_2008_avg,paris_2009_avg,paris_2010_avg,paris_2019_avg,paris_2020_avg,paris_2021_avg]
newyork = [newyork_2008_avg,newyork_2009_avg,newyork_2010_avg,newyork_2019_avg,newyork_2020_avg,newyork_2021_avg]

index = ['2008','2009','2010','2019','2020','2021']

df = pd.DataFrame({'Paris': paris,
                   'New York': newyork}, index = index)

graph = df.plot.bar(rot = 45, color ={"Paris" : "red", "New York": "green"}, alpha = .75, figsize = (9,5))
plt.title("Average Review Ratings Of Paris & New York")
plt.xlabel("Years")
plt.ylabel("Review Ratings")
plt.legend(["P", "NY"] , loc = 'center', fontsize = 9)
plt.tight_layout()
plt.savefig("fig2_NY&Paris.png")
plt.show()

# %%
paris = [paris_2008_avg,paris_2009_avg,paris_2010_avg,paris_2019_avg,paris_2020_avg,paris_2021_avg]
newyork = [newyork_2008_avg,newyork_2009_avg,newyork_2010_avg,newyork_2019_avg,newyork_2020_avg,newyork_2021_avg]
paris_max = [paris_2008_max,paris_2009_max,paris_2010_max,paris_2019_max,paris_2020_max,paris_2021_max]
paris_min = [paris_2008_min,paris_2009_min,paris_2010_min,paris_2019_min,paris_2020_min,paris_2021_min]
newyork_max = [newyork_2008_max,newyork_2008_max,newyork_2008_max,newyork_2008_max,newyork_2008_max,newyork_2008_max] 
newyork_min = [newyork_2008_min,newyork_2009_min,newyork_2010_min,newyork_2019_min,newyork_2020_min,newyork_2021_min]

index = ['2008','2009','2010','2019','2020','2021']

df = pd.DataFrame({'Paris': paris,'New York': newyork,
                   'P Max': paris_max, 'P Min': paris_min,
                   'NY Max': newyork_max, 'NY Min': newyork_min}, index = index)

graph = df.plot.bar(rot = 45, color ={"Paris" : "red", "New York": "green", "P Max": "blue", "P Min": "yellow", "NY Max": "coral", "NY Min": "violet"}, alpha = .75, figsize = (9,5))
plt.title("Average Review Ratings Of Paris & New York + Max & Min")
plt.xlabel("Years")
plt.ylabel("Review Ratings")
plt.legend(["P", "NY", "P Max","P Min","NY Max","NY Min"],loc = 'center', fontsize = 9)
plt.show()
